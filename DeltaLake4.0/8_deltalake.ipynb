# %% [markdown]
# # **Universal Format**

# %%
# %sql
CREATE TABLE deltalaketest.default.unitbl USING DELTA TBLPROPERTIES(
  'delta.enableIcebergCompatV2' = 'true',
  'delta.universalFormat.enabledFormats' = 'iceberg');

--Code to set up a table in universal format for iceberg

# %%
# %sql
INSERT INTO deltalaketest.default.unitbl
