# %% [markdown]
# # **Change Data Feed**

# %%
# %sql
ALTER TABLE deltalaketest.default.clonetbl
SET TBLPROPERTIES (delta.enableChangeDataFeed = true)

--Sets the table properties to enable change data feed

# %%
# %sql
SELECT * FROM deltalaketest.default.clonetbl

--Query the data

# %%
# %sql
INSERT INTO deltalaketest.default.clonetbl
VALUES (10, 100, 'zz', 1)

--Code to insert records

# %%
# %sql
DESCRIBE HISTORY deltalaketest.default.clonetbl

--Code for history/versioning

# %%
# %sql
SELECT * FROM table_changes('deltalaketest.default.clonetbl',1)

--Code query data table changes. 1 is for the starting version
